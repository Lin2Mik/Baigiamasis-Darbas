# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO  # Formuoja str tipo duomenis į StringIO objektą vėlesniam naudojimui
from tabulate import tabulate
from urllib.parse import urljoin  # Gražiai sujungia bazinę nuorodą su 'endpoint'
import re
import datetime as dt

# %% [markdown]
# ***Funkcijos***

# %%
def get_soup(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup

def lenteliu_formavimas(lenteles, data, spausdinti=False): # Funkcija naudojama "išvirus sriubą" su Beautiful soup
    if lenteles:
        duomenys = [data]
        for i in range(len(lenteles)):
            lenteles_html = str(lenteles[i]) # Sriubos elementą paverčiam į str tipą
            df = pd.read_html(StringIO(lenteles_html), thousands=None, header=0)[0] # Str turinį su 'StringIO' imituoja kaip failą, kad pandas suformmatuotų jį į DataFrame
            df.dropna(how='all', axis=1, inplace=True)
            df.dropna(how='all', axis=0, inplace=True)
            df.fillna('', inplace=True)

            # Keičiame , į . kad vėliau būtų paprasta skaičiuoti arba atvaizduoti kaip float tipą jei prireiks
            for column in df.columns:
                df[column] = df[column].astype(str)
                df[column] = df[column].str.replace(',', '.', regex=False)
            
            if spausdinti:
                print(f"{data} Lentelė {i+1}")
                print(tabulate(df, headers='keys', tablefmt='grid'))
                print("\n")
            duomenys.append(df)
        return duomenys
    else:
        print("Lentelių nerasta.")


def prideti_lentele(sarasas):  # Funkciją naudoti galima įvedant duomenis rankiniu būdu
    tarifas = input("Įveskite tarifą (pvz., Standartinis Planas): ")
    dedamoji = input("Įveskite dedamosios pavadinimą: ")
    kaina = float(input("Įveskite kainą be PVM: "))
    pvm = 1.21
    kaina_su_pvm = kaina * pvm
    sarasas.append({'Tarifas': tarifas, 'Dedamoji': dedamoji, 'Kaina be PVM': kaina, 'Kaina su PVM': kaina_su_pvm})

# %% [markdown]
# ***Nuorodų surinkimas į list.***
#
# Nuorodas renkuosi dėl skirtingų jų pavadinimų bei skirtingų informacijos padavimo būdų.
# Formuoju dictionary, kad suporuoti datas su lentelėmis
#
# 'Pastaba, atnaujinimas įvyko liepos 22d.'

# %%
link = 'https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai-eso-galiojantys.aspx' # Pradinė nuoroda el. kainų filtravimui
pradine_sriuba = get_soup(link)

pagr_link = 'https://www.regula.lt' # Nuorodų 'lipdymui'
link_sar = []
for link in pradine_sriuba.find_all('a'): # 'a' ieškomos visos eilutės kuriose yra po nuorodą
    href = link.get('href') # href yra Hypertext Reference, žymė kuri pradeda nuorodą ('link')
    if href:
        full_url = urljoin(pagr_link, href) # Gražiai sujungia bazinę nuorodą su 'endpoint'
        text = link.text.strip() # Paliekamas tik tekstas susijęs su nuoroda
        if 'visuomeniniai tarifai' in text.lower(): # Filtruoju nuorodas pagal raktinius žodžius
            dict = {text: full_url}
            link_sar.append(dict)
            print(f'{text}, URL: {full_url}') # Spausdinti rezultatus, pasitikrinti output ar viskas tinka
# Out:
# Visuomeniniai tarifai (UAB „Ignitis“), URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai-eso-galiojantys.aspx
# ​Visuomeniniai tarifai, galiojantys iki 2024-03-31, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/2023/visuomeniniai-tarifai-galioje-iki-2024-03-31.aspx
# Visuomeniniai tarifai, galioję iki 2023-12-31​, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/2023/Visuomeniniai-tarifai-galioje-iki-2023-12-31.aspx
# Visuomeniniai tarifai, galioję iki 2023-07-01​, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/2023/visuomeniniai-tarifai-galioje-iki-2023-07-01.aspx
# Visuomeniniai tarifai, ​galioję iki 20​2​3-03-01​​​, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/2023/visuomeniniai-tarifai-iki-2023-03-01.aspx
# Visuomeniniai tarifai, galioję iki 2022-12-31​, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai-galioje-iki-2022-gruodzio-31.aspx
# Visuomeniniai tarifai, galioję iki 2021-12-31​, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomenines-elektros-energijos-kainos.aspx
# Visuomeniniai tarifai, galioję iki 2​02​1-06​-30​​​​, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai-galioje-iki-2021-06-30.aspx
# Visuomeniniai tarifai, galioję iki 2020-12-31, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai-galioje-iki-2020-12-31.aspx
# Visuomeniniai tarifai, galioję iki 2020-06-30, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/Visuomeniniai-tarifai%2c-galioj%c4%99-iki-2020-m--bir%c5%beelio-.aspx
# Visuomeniniai tarifai, galioję iki 2019-12-31, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai%2c-galioj%c4%99-iki-2019-12-31.aspx
# Visuomeniniai tarifai, galioję iki 2018-12-31, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai-galioje-iki-2018-12-31.aspx
# Visuomeniniai tarifai, galioję iki 2017-12-31, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai-ab-ENERGIJOS-SKIRSTYMO-OPERATORIUS-nuo-2017-m--sausio-1-d.aspx
# Visuomeniniai tarifai, galioję iki 2016-12-31, URL: https://www.regula.lt/elektra/Puslapiai/tarifai/visuomeniniai-tarifai-galioje-iki-2016-m--gruodzio-31-d.aspx
# Visuomeniniai tarifai, galioję iki 2016-06-30, URL: https://www.regula.lt/elektra/Puslapiai/visuomeniniai-tarifai-2016-01-01-2016-07-01.aspx
# Visuomeniniai tarifai, galioję iki 2015-12-31, URL: https://www.regula.lt/elektra/Puslapiai/visuomeniniai-tarifai-2015-m.aspx

# %% [markdown]
# Pasitikrinu informaciją iš nuorodų:
# Ar yra lentelės, jei yra atsipausdinti rezultatus.
# Jei lentelių nerasta atspausdinu nuorodą kurioje lentelės nerastos arba pateiktos neteisingai.
# Rankiniu būdu vėliau suvesti duomenis.

# %%
spausdinti_lenteles = True # Jeigu reikia atvaizdavimo output pasižiūrėti kokią informaciją pavyko gauti
duomenu_sar = [] # Suformuojamas duomenų sąrašas
datos_tvarkymui = [] # Iš kurios datos duomenis reikės tvarkyti rankiniu būdu
for el in link_sar: # Imu iš sąrašo indeksą su elementu ('el'), elemente yra key: value įrašyta informacija
    for text, link in el.items():       
        sriuba = get_soup(link)
        lenteles = sriuba.find_all('table') # Daugiskaita, nes lentelių gali būti ne viena
        clean_text = text.replace('\u200b', '')  # Iš html atsiradusi vertė '\n200b' ją reikia pašalinti, kad galėčiau filtruoti su ReGex

        # Regex pagalba filtruojama data YYYY-MM-DD
        pattern = r'\d{4}-\d{2}-\d{2}' # d - digits žymė ir kiek skaitmenų paimti turi
        match = re.search(pattern, clean_text)
        if match:
            date = match.group()
            print('Kainos suformavimo data:', date)
        elif 'Ignitis' in clean_text:
            date = '2024-07-01'
            print('Kainos suformavimo data:', date)
        
        if len(lenteles) == 0:
            print('Tvarkyti rankiniu būdu šią nuorodą:\n', link)
            datos_tvarkymui.append(date)
            continue

        print(f"Kiek lentelių randu: {len(lenteles)}")
        df_lenteles = lenteliu_formavimas(lenteles, date, spausdinti_lenteles)
        # lenteliu_formavimas(lenteles, spausdinti_lenteles)
        duomenu_sar.append(df_lenteles)
# Out:
# Kainos suformavimo data: 2024-07-01
# Kiek lentelių randu: 4
# 2024-07-01 Lentelė 1
# +----+--------------------------+--------------------------------+-----------------------------------+
# |    | ŽĮ ​​                      | ​                               |   2024 m. II pusm.  ct/kWh su PVM |
# +====+==========================+================================+===================================+
# |  0 | Viena  laiko zona        | Standartinis                   |                             0.197 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  1 | Dvi laiko zonos ​​         | Dieninė  dedamoji              |                             0.225 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  2 |                          | Naktinė  dedamoji              |                             0.133 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  3 | Planas „Namai“ ​​ ​​ ​​ ​       | Pastovioji  dedamoji. EUR/mėn. |                             3     |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  4 |                          | Viena  laiko zona              |                             0.181 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  5 |                          | Dvi  laiko zonos               |                             0.207 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  6 |                          | Naktinė  dedamoji              |                             0.123 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  7 | Planas „Namai plius“ ​​ ​​ ​​ ​​ | Pastovioji  dedamoji. EUR/mėn. |                             6     |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  8 |                          | Viena  laiko zona              |                             0.177 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# |  9 |                          | Dvi  laiko zonos               |                             0.202 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# | 10 |                          | Naktinė  dedamoji              |                             0.121 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# | 11 | Planas „Išmanusis“ ​​ ​​ ​    | Nakties  energijos dedamoji    |                             0.13  |
# +----+--------------------------+--------------------------------+-----------------------------------+
# | 12 |                          | Ryto  energijos dedamoji       |                             0.148 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# | 13 |                          | Dienos  energijos dedamoji     |                             0.189 |
# +----+--------------------------+--------------------------------+-----------------------------------+
# | 14 |                          | Vakaro  energijos dedamoji     |                             0.228 |
# +----+--------------------------+--------------------------------+-----------------------------------+
#
#
# 2024-07-01 Lentelė 2
# +----+-----------------------------------+---------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |    | Tarifai, jų dedamosios            | Tarifai, jų dedamosios.1                                | Mato vnt.                         | ​​​​Kaina​                             | ​​​​Kaina​.1                           |
# +====+===================================+=========================================================+===================================+===================================+===================================+
# |  0 | Tarifai. jų dedamosios            | Tarifai. jų dedamosios                                  | Mato vnt.                         |                                   |                                   |
# +----+-----------------------------------+---------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  1 | be PVM                            | su  PVM                                                 |                                   |                                   |                                   |
# +----+-----------------------------------+---------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  2 | 7.1.  Vienos laiko zonos tarifas: | 7.1.  Vienos laiko zonos tarifas:                       | 7.1.  Vienos laiko zonos tarifas: | 7.1.  Vienos laiko zonos tarifas: | 7.1.  Vienos laiko zonos tarifas: |
# +----+-----------------------------------+---------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  3 |                                   | Vienos  laiko zonos energijos dedamoji                  | EUR/kWh                           | 0.107                             | 0.13                              |
# +----+-----------------------------------+---------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  4 | 7.2. Dvi​ejų laiko zonų tarifas:   | 7.2. Dvi​ejų laiko zonų tarifas:                         | 7.2. Dvi​ejų laiko zonų tarifas:   | 7.2. Dvi​ejų laiko zonų tarifas:   | 7.2. Dvi​ejų laiko zonų tarifas:   |
# +----+-----------------------------------+---------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  5 |                                   | Dieninė  energijos dedamoji                             | EUR/kWh                           | 0.121                             | 0.147                             |
# +----+-----------------------------------+---------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  6 |                                   | Naktinė. šeštadienio ir sekmadienio energijos  dedamoji | EUR/kWh                           | 0.074                             | 0.089                             |
# +----+-----------------------------------+---------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
#
#
# 2024-07-01 Lentelė 3
# +----+----------------------+-------------------------------+----------------------------------+
# |    | ŽĮ ​​​​​                  | ŽĮ ​​​​​.1                         | 2024 m. I pusm. Eur/kWh su PVM   |
# +====+======================+===============================+==================================+
# |  0 | Viena laiko zona     | Standartinis                  | 0.214                            |
# +----+----------------------+-------------------------------+----------------------------------+
# |  1 | Dvi laiko zonos​      | Dieninė dedamoji              | 0.245                            |
# +----+----------------------+-------------------------------+----------------------------------+
# |  2 | Dvi laiko zonos​      | Naktinė dedamoji              | 0.148                            |
# +----+----------------------+-------------------------------+----------------------------------+
# |  3 | ​​Planas „Namai“       | Pastovioji dedamoji. EUR/mėn. | 3                                |
# +----+----------------------+-------------------------------+----------------------------------+
# |  4 | ​​Planas „Namai“       | Viena laiko zona              | 0.198                            |
# +----+----------------------+-------------------------------+----------------------------------+
# |  5 | ​​Planas „Namai“       | Dvi laiko zonos               | 0.227                            |
# +----+----------------------+-------------------------------+----------------------------------+
# |  6 | ​​Planas „Namai“       | Naktinė dedamoji              | 0.138                            |
# +----+----------------------+-------------------------------+----------------------------------+
# |  7 | ​​Planas „Namai plius“ | Pastovioji dedamoji. EUR/mėn. | 6                                |
# +----+----------------------+-------------------------------+----------------------------------+
# |  8 | ​​Planas „Namai plius“ | Viena laiko zona              | 0.195                            |
# +----+----------------------+-------------------------------+----------------------------------+
# |  9 | ​​Planas „Namai plius“ | Dvi laiko zonos               | 0.222                            |
# +----+----------------------+-------------------------------+----------------------------------+
# | 10 | ​​Planas „Namai plius“ | Naktinė dedamoji              | 0.136                            |
# +----+----------------------+-------------------------------+----------------------------------+
# | 11 | ​​Planas „Išmanusis“   | Nakties energijos dedamoji    | 0.144                            |
# +----+----------------------+-------------------------------+----------------------------------+
# | 12 | ​​Planas „Išmanusis“   | Ryto energijos dedamoji       | 0.162                            |
# +----+----------------------+-------------------------------+----------------------------------+
# | 13 | ​​Planas „Išmanusis“   | Dienos energijos dedamoji     | 0.208​                            |
# +----+----------------------+-------------------------------+----------------------------------+
# | 14 | ​​Planas „Išmanusis“   | Vakaro energijos dedamoji     | 0.248                            |
# +----+----------------------+-------------------------------+----------------------------------+
#
#
# 2024-07-01 Lentelė 4
# +----+-----------------------------------+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |    | Tarifai, jų dedamosios            | Tarifai, jų dedamosios.1                               | Mato vnt.                         | ​​​Kaina​                             | ​​​Kaina​.1                           |
# +====+===================================+========================================================+===================================+===================================+===================================+
# |  0 | Tarifai. jų dedamosios            | Tarifai. jų dedamosios                                 | Mato vnt.                         |                                   |                                   |
# +----+-----------------------------------+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  1 | be PVM                            | su PVM                                                 |                                   |                                   |                                   |
# +----+-----------------------------------+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  2 | 7. 1. Vienos laiko zonos tarifas: | 7. 1. Vienos laiko zonos tarifas:                      | 7. 1. Vienos laiko zonos tarifas: | 7. 1. Vienos laiko zonos tarifas: | 7. 1. Vienos laiko zonos tarifas: |
# +----+-----------------------------------+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  3 |                                   | Vienos laiko zonos energijos dedamoji                  | EUR/kWh                           | 0.121                             | 0.147                             |
# +----+-----------------------------------+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  4 | ​7.2. Dvi​ejų laiko zonų tarifas:   | ​7.2. Dvi​ejų laiko zonų tarifas:                        | ​7.2. Dvi​ejų laiko zonų tarifas:   | ​7.2. Dvi​ejų laiko zonų tarifas:   | ​7.2. Dvi​ejų laiko zonų tarifas:   |
# +----+-----------------------------------+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  5 |                                   | Dieninė energijos dedamoji                             | EUR/kWh                           | 0.139                             | 0.168                             |
# +----+-----------------------------------+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  6 |                                   | Naktinė. šeštadienio ir sekmadienio energijos dedamoji | EUR/kWh                           | 0.086                             | 0.104                             |
# +----+-----------------------------------+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
#
#
# Kainos suformavimo data: 2024-03-31
# Kiek lentelių randu: 2
# 2024-03-31 Lentelė 1
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |    | ŽĮ ​                  | ŽĮ ​.1                            | Mato vnt.   | 2024 m. I pusm.   | 2024 m. I pusm..1   |
# +====+======================+==================================+=============+===================+=====================+
# |  0 | ŽĮ ​                  | ŽĮ ​                              | Mato vnt.   | 2024 m. I pusm.   | 2024 m. I pusm.     |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  1 | ŽĮ ​                  | ŽĮ ​                              | Mato vnt.   | 2024 m. I pusm.   | 2024 m. I pusm.     |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  2 | Viena laiko zona     | „Standartinis“                   | EUR/kWh     | 0.219             | 0.219               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  3 | Dvi laiko zonos      | „Standartinis“. dieninė dedamoji | EUR/kWh     | 0.250             | 0.250               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  4 | Dvi laiko zonos      | naktinė dedamoji                 | EUR/kWh     | 0.152             | 0.152               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  5 | Planas „Namai“       | Pastovioji dedamoji. EUR/mėn.    | EUR/kWh     | 3.00              | 3.00                |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  6 | Planas „Namai“       | Viena laiko zona                 | EUR/kWh     | 0.203             | 0.203               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  7 | Planas „Namai“       | Dvi laiko zonos.                 | EUR/kWh     | 0.232             | 0.232               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  8 | Planas „Namai“       | dieninė dedamoji                 | EUR/kWh     | 0.232             | 0.232               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# |  9 | Planas „Namai“       | naktinė dedamoji                 | EUR/kWh     | 0.143             | 0.143               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 10 | Planas „Namai plius“ | Pastovioji dedamoji. EUR         | EUR/kWh     | 6.00              | 6.00                |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 11 | Planas „Namai plius“ | Viena laiko zona                 | EUR/kWh     | 0.200             | 0.200               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 12 | Planas „Namai plius“ | Dvi laiko zonos.                 | EUR/kWh     | 0.227             | 0.227               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 13 | Planas „Namai plius“ | dieninė dedamoji                 | EUR/kWh     | 0.227             | 0.227               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 14 | Planas „Namai plius“ | naktinė dedamoji                 | EUR/kWh     | 0.140             | 0.140               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 15 | Planas „Išmanusis“   | Nakties energijos dedamoji       | EUR/kWh     | 0.149             | 0.149               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 16 | Planas „Išmanusis“   | Ryto energijos dedamoji          | EUR/kWh     | 0.167             | 0.167               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 17 | Planas „Išmanusis“   | Dienos energijos dedamoji        | EUR/kWh     | 0.213             | 0.213               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
# | 18 | Planas „Išmanusis“   | Vakaro energijos dedamoji        | EUR/kWh     | ​​0.253             | ​​0.253               |
# +----+----------------------+----------------------------------+-------------+-------------------+---------------------+
#
#
# 2024-03-31 Lentelė 2
# +----+----------------------------------+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |    | Tarifai, jų dedamosios           | Tarifai, jų dedamosios.1                               | Mato vnt.                        | ​​Kaina​                            | ​​Kaina​.1                          |
# +====+==================================+========================================================+==================================+==================================+==================================+
# |  0 | Tarifai. jų dedamosios           | Tarifai. jų dedamosios                                 | Mato vnt.                        |                                  |                                  |
# +----+----------------------------------+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  1 | be PVM                           | su PVM                                                 |                                  |                                  |                                  |
# +----+----------------------------------+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  2 | 7.1. Vienos laiko zonos tarifas: | 7.1. Vienos laiko zonos tarifas:                       | 7.1. Vienos laiko zonos tarifas: | 7.1. Vienos laiko zonos tarifas: | 7.1. Vienos laiko zonos tarifas: |
# +----+----------------------------------+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  3 |                                  | Vienos laiko zonos energijos dedamoji                  | EUR/kWh                          | 0.126                            | 0.152                            |
# +----+----------------------------------+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  4 | ​7.2. Dvi​ejų laiko zonų tarifas:  | ​7.2. Dvi​ejų laiko zonų tarifas:                        | ​7.2. Dvi​ejų laiko zonų tarifas:  | ​7.2. Dvi​ejų laiko zonų tarifas:  | ​7.2. Dvi​ejų laiko zonų tarifas:  |
# +----+----------------------------------+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  5 |                                  | Dieninė energijos dedamoji                             | EUR/kWh                          | 0.143                            | 0.173                            |
# +----+----------------------------------+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  6 |                                  | Naktinė. šeštadienio ir sekmadienio energijos dedamoji | EUR/kWh                          | 0.09                             | 0.109​                            |
# +----+----------------------------------+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+
#
#
# Kainos suformavimo data: 2023-12-31
# Kiek lentelių randu: 2
# 2023-12-31 Lentelė 1
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |    | Planai                    | ​                                                       | Mato vnt.   | 2023 m. kovo-birželio mėn. su tiekimo kainos kompensacija (su PVM)   | 2023 m. II pusmetis (su PVM)   |
# +====+===========================+========================================================+=============+======================================================================+================================+
# |  0 | ​​Plan​as „Standartinis“  ​ ​ ​ | Vienos laiko zonos energijos dedamoji                  | ​Eur/kWh     | 0.280                                                                | 0.227                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  1 | ​​Plan​as „Standartinis“  ​ ​ ​ | Dviejų laiko zonų                                      |             | ​                                                                     | ​                               |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  2 | ​​Plan​as „Standartinis“  ​ ​ ​ | dieninė energijos dedamoji                             | Eur/kWh     | 0.280                                                                | 0.261                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  3 | ​​Plan​as „Standartinis“  ​ ​ ​ | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.193                                                                | 0.158                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  4 | ​​​Planas „Namai“ ​ ​ ​ ​        | Pastovioji dedamoji                                    | Eur/mėn.    | 3.00                                                                 | 3.00                           |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  5 | ​​​Planas „Namai“ ​ ​ ​ ​        | Vienos laiko zonos energijos dedamoji                  | Eur/kWh     | 0.265                                                                | 0.211                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  6 | ​​​Planas „Namai“ ​ ​ ​ ​        | Dviejų laiko zonų                                      |             | ​                                                                     | ​                               |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  7 | ​​​Planas „Namai“ ​ ​ ​ ​        | dieninė energijos dedamoji                             | Eur/kWh     | 0.280                                                                | 0.243                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  8 | ​​​Planas „Namai“ ​ ​ ​ ​        | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.183                                                                | 0.149                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  9 | ​​​Planas „Namai plus“ ​ ​ ​ ​   | Pastovioji dedamoji                                    | Eur/mėn.    | 6.00                                                                 | 6.00                           |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# | 10 | ​​​Planas „Namai plus“ ​ ​ ​ ​   | Vienos laiko zonos energijos dedamoji                  | Eur/kWh     | 0.261                                                                | 0.208                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# | 11 | ​​​Planas „Namai plus“ ​ ​ ​ ​   | Dviejų laiko zonų                                      |             | ​                                                                     | ​                               |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# | 12 | ​​​Planas „Namai plus“ ​ ​ ​ ​   | dieninė energijos dedamoji                             | Eur/kWh     | 0.280                                                                | 0.238                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# | 13 | ​​​Planas „Namai plus“ ​ ​ ​ ​   | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.181                                                                | 0.146                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# | 14 | ​​​Planas „Išmanusis“ ​ ​ ​     | Nakties energijos dedamoji                             | Eur/kWh     | 0.191                                                                | 0.155                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# | 15 | ​​​Planas „Išmanusis“ ​ ​ ​     | Ryto energijos dedamoji                                | Eur/kWh     | 0.210                                                                | 0.172                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# | 16 | ​​​Planas „Išmanusis“ ​ ​ ​     | Dienos energijos dedamoji                              | Eur/kWh     | 0.275                                                                | 0.224                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# | 17 | ​​​Planas „Išmanusis“ ​ ​ ​     | Vakaro energijos dedamoji                              | Eur/kWh     | 0.280                                                                | 0.260                          |
# +----+---------------------------+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
#
#
# 2023-12-31 Lentelė 2
# +----+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |    | Unnamed: 0                                             | Mato vnt.   | 2023 m. kovo-birželio mėn. su tiekimo kainos kompensacija (su PVM)   | 2023 m. II pusmetis (su PVM)   |
# +====+========================================================+=============+======================================================================+================================+
# |  0 | Vienos laiko zonos energijos dedamoji                  | ​​Eur/kWh     | 0.221                                                                | 0.168                          |
# +----+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  1 | Dviejų laiko zonų                                      |             | ​                                                                     | ​                               |
# +----+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  2 | dieninė energijos dedamoji                             | Eur/kWh     | 0.252                                                                | 0.193                          |
# +----+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
# |  3 | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.153                                                                | 0.119                          |
# +----+--------------------------------------------------------+-------------+----------------------------------------------------------------------+--------------------------------+
#
#
# Kainos suformavimo data: 2023-07-01
# Kiek lentelių randu: 2
# 2023-07-01 Lentelė 1
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |    | Planai                   | ​​                                                       | Mato vnt.   | 2023 m. kovo-birželio mėn. be tiekimo kainos kompensacijos (su PVM)   | 2023 m. kovo-birželio mėn. su tiekimo kainos kompensacija (su PVM)   |
# +====+==========================+========================================================+=============+=======================================================================+======================================================================+
# |  0 | ​​Planas „Standartinis“​ ​ ​ ​ | Vienos laiko zonos energijos dedamoji                  | Eur/kWh     | 0.280                                                                 | 0.280                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  1 | ​​Planas „Standartinis“​ ​ ​ ​ | Dviejų laiko zonų                                      |             | ​                                                                      | ​                                                                     |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  2 | ​​Planas „Standartinis“​ ​ ​ ​ | dieninė energijos dedamoji                             | Eur/kWh     | 0.320                                                                 | 0.280                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  3 | ​​Planas „Standartinis“​ ​ ​ ​ | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.193                                                                 | 0.193                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  4 | ​​​Planas „Namai“ ​ ​ ​ ​       | Pastovioji dedamoji                                    | Eur/mėn.    | 3.00                                                                  | 3.00                                                                 |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  5 | ​​​Planas „Namai“ ​ ​ ​ ​       | Vienos laiko zonos energijos dedamoji                  | Eur/kWh     | 0.265                                                                 | 0.265                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  6 | ​​​Planas „Namai“ ​ ​ ​ ​       | Dviejų laiko zonų                                      |             | ​                                                                      | ​                                                                     |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  7 | ​​​Planas „Namai“ ​ ​ ​ ​       | dieninė energijos dedamoji                             | Eur/kWh     | 0.302                                                                 | 0.280                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  8 | ​​​Planas „Namai“ ​ ​ ​ ​       | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.183                                                                 | 0.183                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  9 | ​​​Planas „Namai plus“ ​ ​ ​ ​  | Pastovioji dedamoji                                    | Eur/mėn.    | 6.00                                                                  | 6.00                                                                 |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# | 10 | ​​​Planas „Namai plus“ ​ ​ ​ ​  | Vienos laiko zonos energijos dedamoji                  | Eur/kWh     | 0.261                                                                 | 0.261                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# | 11 | ​​​Planas „Namai plus“ ​ ​ ​ ​  | Dviejų laiko zonų                                      |             | ​                                                                      | ​                                                                     |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# | 12 | ​​​Planas „Namai plus“ ​ ​ ​ ​  | dieninė energijos dedamoji                             | Eur/kWh     | 0.297                                                                 | 0.280                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# | 13 | ​​​Planas „Namai plus“ ​ ​ ​ ​  | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.181                                                                 | 0.181                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# | 14 | ​​​Planas „Išmanusis“ ​ ​ ​    | Nakties energijos dedamoji                             | Eur/kWh     | 0.191                                                                 | 0.191                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# | 15 | ​​​Planas „Išmanusis“ ​ ​ ​    | Ryto energijos dedamoji                                | Eur/kWh     | 0.210                                                                 | 0.210                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# | 16 | ​​​Planas „Išmanusis“ ​ ​ ​    | Dienos energijos dedamoji                              | Eur/kWh     | 0.275                                                                 | 0.275                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# | 17 | ​​​Planas „Išmanusis“ ​ ​ ​    | Vakaro energijos dedamoji                              | Eur/kWh     | 0.314                                                                 | 0.280                                                                |
# +----+--------------------------+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
#
#
# 2023-07-01 Lentelė 2
# +----+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |    | Unnamed: 0                                             | Mato vnt.   | 2023 m. kovo-birželio mėn. be tiekimo kainos kompensacijos (su PVM)   | 2023 m. kovo-birželio mėn. su tiekimo kainos kompensacija (su PVM)   |
# +====+========================================================+=============+=======================================================================+======================================================================+
# |  0 | Vienos laiko zonos energijos dedamoji​​                  | Eur/kWh     | 0.221                                                                 | 0.221                                                                |
# +----+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  1 | Dviejų laiko zonų                                      |             | ​                                                                      | ​                                                                     |
# +----+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  2 | dieninė energijos dedamoji                             | Eur/kWh     | 0.252                                                                 | 0.252                                                                |
# +----+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
# |  3 | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.153                                                                 | 0.153                                                                |
# +----+--------------------------------------------------------+-------------+-----------------------------------------------------------------------+----------------------------------------------------------------------+
#
#
# Kainos suformavimo data: 2023-03-01
# Kiek lentelių randu: 2
# 2023-03-01 Lentelė 1
# +----+----------------------------+--------------------------------------------------------+-------------+---------------------------------------------------------------+--------------------------------------------------------------+
# |    | Planai                     | ​                                                       | Mato vnt.   | 2023 m. I pusmečio be tiekimo kainos kompensacijos (su PVM)   | 2023 m. I pusmečio su tiekimo kainos kompensacija (su PVM)   |
# +====+============================+========================================================+=============+===============================================================+==============================================================+
# |  0 | ​​Planas „Standartinis“  ​ ​ ​ ​ | Vienos laiko zonos energijos dedamoji                  | ​Eur/kWh     | 0.565                                                         | 0.280                                                        |
# +----+----------------------------+--------------------------------------------------------+-------------+---------------------------------------------------------------+--------------------------------------------------------------+
# |  1 | ​​Planas „Standartinis“  ​ ​ ​ ​ | Dviejų laiko zonų                                      |             | ​                                                              | ​                                                             |
# +----+----------------------------+--------------------------------------------------------+-------------+---------------------------------------------------------------+--------------------------------------------------------------+
# |  2 | ​​Planas „Standartinis“  ​ ​ ​ ​ | dieninė energijos dedamoji                             | Eur/kWh     | 0.630                                                         | 0.345                                                        |
# +----+----------------------------+--------------------------------------------------------+-------------+---------------------------------------------------------------+--------------------------------------------------------------+
# |  3 | ​​Planas „Standartinis“  ​ ​ ​ ​ | naktinė. šeštadienio ir sekmadienio energijos dedamoji | Eur/kWh     | 0.425                                                         | 0.280                                                        |
# +----+----------------------------+--------------------------------------------------------+-------------+---------------------------------------------------------------+--------------------------------------------------------------+
# ...
# +====+========================================================+==================================+==================================+==================================+==================================+==================================+
# |  0 | Tarifai. jų dedamosios                                 | Mato vnt.                        |                                  |                                  |                                  |                                  |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  1 | Tarifai. jų dedamosios                                 | Mato vnt.                        |                                  |                                  |                                  |                                  |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  2 | Tarifai. jų dedamosios                                 | Mato vnt.                        |                                  |                                  |                                  |                                  |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  3 | Namai                                                  | Namai                            | Namai plius                      | Namai plius                      |                                  |                                  |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  4 | Kaina                                                  | Kaina                            | Kaina                            | Kaina                            |                                  |                                  |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  5 | be PVM                                                 | su PVM                           | be PVM                           | su PVM                           |                                  |                                  |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  6 | 9.1. Vienos laiko zonos tarifas:                       | 9.1. Vienos laiko zonos tarifas: | 9.1. Vienos laiko zonos tarifas: | 9.1. Vienos laiko zonos tarifas: | 9.1. Vienos laiko zonos tarifas: | 9.1. Vienos laiko zonos tarifas: |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  7 | ​pastovioji dedamoji                                    | Lt/mėn.​                          | 8.25                             | 9.98                             | 16.54                            | 19.99                            |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  8 | ​vienos laiko zonos energijos dedamoji                  | ct/kWh                           | 32.8                             | 39.7                             | 31.4                             | 38.                              |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# |  9 | 9.2. Dviejų laiko zonų tarifas:                        | 9.2. Dviejų laiko zonų tarifas:  | 9.2. Dviejų laiko zonų tarifas:  | 9.2. Dviejų laiko zonų tarifas:  | 9.2. Dviejų laiko zonų tarifas:  | 9.2. Dviejų laiko zonų tarifas:  |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# | 10 | ​pastovioji dedamoji                                    | ​Lt/mėn.                          | 8.25                             | 9.98                             | ​16.54                            | 19.99                            |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# | 11 | ​dieninė energijos dedamoji                             | ct/kWh                           | 35.6                             | 43.2                             | 33.8                             | 41.1                             |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
# | 12 | ​naktinė. šeštadienio ir sekmadienio energijos dedamoji | ​ ct/kWh                          | 26.2                             | 31.8                             | 25.6                             | 30.7                             |
# +----+--------------------------------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+----------------------------------+
#
#
# 2015-12-31 Lentelė 5
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |    | Tarifai, jų dedamosios                                 | Mato vnt.                         | Kaina                             | Kaina.1                           | Kaina.2                           | Kaina.3                           |
# +====+========================================================+===================================+===================================+===================================+===================================+===================================+
# |  0 | Tarifai. jų dedamosios                                 | Mato vnt.                         |                                   |                                   |                                   |                                   |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  1 | be PVM                                                 | su PVM                            | su PVM                            | su PVM                            |                                   |                                   |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  2 | 10.1. Vienos laiko zonos tarifas:                      | 10.1. Vienos laiko zonos tarifas: | 10.1. Vienos laiko zonos tarifas: | 10.1. Vienos laiko zonos tarifas: | 10.1. Vienos laiko zonos tarifas: | 10.1. Vienos laiko zonos tarifas: |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  3 | ​ vienos laiko zonos energijos dedamoji                 | ​euro ct/kWh                       | 8.8                               | 10.6                              | 10.6                              | 10.6                              |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  4 | 10.2. Dviejų laiko zonų tarifas:                       | 10.2. Dviejų laiko zonų tarifas:  | 10.2. Dviejų laiko zonų tarifas:  | 10.2. Dviejų laiko zonų tarifas:  | 10.2. Dviejų laiko zonų tarifas:  | 10.2. Dviejų laiko zonų tarifas:  |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  5 | ​dieninė energijos dedamoji                             | ​euro ct/kWh                       | ​9.5                               | 11.5                              | 11.5                              | 11.5                              |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  6 | ​naktinė. šeštadienio ir sekmadienio energijos dedamoji | ​euro ct/kWh                       | 7.4                               | 8.9                               | 8.9                               | 8.9                               |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
#
#
# 2015-12-31 Lentelė 6
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |    | Tarifai, jų dedamosios                                 | Mato vnt.                         | Kaina                             | Kaina.1                           | Kaina.2                           | Kaina.3                           |
# +====+========================================================+===================================+===================================+===================================+===================================+===================================+
# |  0 | Tarifai. jų dedamosios                                 | Mato vnt.                         |                                   |                                   |                                   |                                   |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  1 | be PVM                                                 | su PVM                            | su PVM                            | su PVM                            |                                   |                                   |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  2 | 10.1. Vienos laiko zonos tarifas:                      | 10.1. Vienos laiko zonos tarifas: | 10.1. Vienos laiko zonos tarifas: | 10.1. Vienos laiko zonos tarifas: | 10.1. Vienos laiko zonos tarifas: | 10.1. Vienos laiko zonos tarifas: |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  3 | ​ vienos laiko zonos energijos dedamoji                 | ct/kWh                            | 30.4                              | 36.6                              | 36.6                              | 36.6                              |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  4 | 10.2. Dviejų laiko zonų tarifas:                       | 10.2. Dviejų laiko zonų tarifas:  | 10.2. Dviejų laiko zonų tarifas:  | 10.2. Dviejų laiko zonų tarifas:  | 10.2. Dviejų laiko zonų tarifas:  | 10.2. Dviejų laiko zonų tarifas:  |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  5 | ​dieninė energijos dedamoji                             | ct/kWh                            | 32.8                              | 39.7                              | 39.7                              | 39.7                              |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
# |  6 | ​naktinė. šeštadienio ir sekmadienio energijos dedamoji | ​ct/kWh                            | 25.6                              | 30.7                              | 30.7                              | 30.7                              |
# +----+--------------------------------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+-----------------------------------+
#
#
# 2015-12-31 Lentelė 7
# +----+--------------------------------------------------+-------------+-----------------+
# |    | ​Paslaugos pavadinimas                            | ​Mato vnt.   | ​Kaina, be PVM   |
# +====+==================================================+=============+=================+
# |  0 | ​Visuomeninio elektros energijos tiekimo paslauga | ​euro ct/kWh | ​0.139           |
# +----+--------------------------------------------------+-------------+-----------------+
#
#
# 2015-12-31 Lentelė 8
# +----+--------------------------------------------------+-------------+-----------------+
# |    | Paslaugos pavadinimas                            | ​Mato vnt.   | ​Kaina, be PVM   |
# +====+==================================================+=============+=================+
# |  0 | ​Visuomeninio elektros energijos tiekimo paslauga | ​ct/kWh      | ​0.481           |
# +----+--------------------------------------------------+-------------+-----------------+

# %% [markdown]
# Info surinkimas iš nuorodos kurioje lentelių nerasta (jos atvaizduotos jpg, png ar kitu formatu)

# %%
pirma_lent = [
    # Standartinis Planas
    {'Tarifas': 'Standartinis Planas', 'Dedamoji': 'Pastovioji dedamoji (EUR/mėn.)', 'Kaina be PVM': 2.48, 'Kaina su PVM': 3.00},
    {'Tarifas': 'Standartinis Planas', 'Dedamoji': 'Energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.138, 'Kaina su PVM': 0.167},
    
    # Namai Planas
    {'Tarifas': 'Namai Planas', 'Dedamoji': 'Pastovioji dedamoji (EUR/mėn.)', 'Kaina be PVM': 4.96, 'Kaina su PVM': 6.00},
    {'Tarifas': 'Namai Planas', 'Dedamoji': 'Energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.125, 'Kaina su PVM': 0.151},
    
    # Namai Plius Planas
    {'Tarifas': 'Namai plius Planas', 'Dedamoji': 'Pastovioji dedamoji (EUR/mėn.)', 'Kaina be PVM': 2.48, 'Kaina su PVM': 3.00},
    {'Tarifas': 'Namai plius Planas', 'Dedamoji': 'Dieninė energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.156, 'Kaina su PVM': 0.189},
    {'Tarifas': 'Namai plius Planas', 'Dedamoji': 'Naktinė energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.102, 'Kaina su PVM': 0.124},
    
    # Išmanusis Planas
    {'Tarifas': 'Išmanusis Planas', 'Dedamoji': 'Pastovioji dedamoji (EUR/mėn.)', 'Kaina be PVM': 4.96, 'Kaina su PVM': 6.00},
    {'Tarifas': 'Išmanusis Planas', 'Dedamoji': 'Dieninė energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.141, 'Kaina su PVM': 0.171},
    {'Tarifas': 'Išmanusis Planas', 'Dedamoji': 'Naktinė energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.095, 'Kaina su PVM': 0.115},
    
    # Keturių laiko zonų Planas
    {'Tarifas': 'Keturių laiko zonų Planas', 'Dedamoji': 'Nakties energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.087, 'Kaina su PVM': 0.105},
    {'Tarifas': 'Keturių laiko zonų Planas', 'Dedamoji': 'Ryto energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.098, 'Kaina su PVM': 0.118},
    {'Tarifas': 'Keturių laiko zonų Planas', 'Dedamoji': 'Dienos energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.126, 'Kaina su PVM': 0.153},
    {'Tarifas': 'Keturių laiko zonų Planas', 'Dedamoji': 'Vakaro energijos kaina (EUR/kWh)', 'Kaina be PVM': 0.150, 'Kaina su PVM': 0.182},
]

antra_lent = [
    # Lentele iš vidutinės įtampos tinklų
    {"Tarifas": "Vienos laiko zonos tarifas", "Dedamoji": "Vienos laiko zonos energijos dedamoji EUR/kWh", "Kaina be PVM": 0.106, "Kaina su PVM": 0.128},
    {"Tarifas": "Dviejų laiko zonų tarifas", "Dedamoji": "Dieninė energijos dedamoji EUR/kWh", "Kaina be PVM": 0.121, "Kaina su PVM": 0.146},
    {"Tarifas": "Dviejų laiko zonų tarifas", "Dedamoji": "Naktinė, Šeštadienio ir sekmadienio energijos dedamoji EUR/kWh", "Kaina be PVM": 0.083, "Kaina su PVM": 0.100}
]

df_1 = pd.DataFrame(pirma_lent)
df_2 = pd.DataFrame(antra_lent)
print(tabulate(df_1, headers='keys', tablefmt='grid', showindex=False))
print(tabulate(df_2, headers='keys', tablefmt='grid', showindex=False))
# Out:
# +---------------------------+-----------------------------------+----------------+----------------+
# | Tarifas                   | Dedamoji                          |   Kaina be PVM |   Kaina su PVM |
# +===========================+===================================+================+================+
# | Standartinis Planas       | Pastovioji dedamoji (EUR/mėn.)    |          2.48  |          3     |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Standartinis Planas       | Energijos kaina (EUR/kWh)         |          0.138 |          0.167 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Namai Planas              | Pastovioji dedamoji (EUR/mėn.)    |          4.96  |          6     |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Namai Planas              | Energijos kaina (EUR/kWh)         |          0.125 |          0.151 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Namai plius Planas        | Pastovioji dedamoji (EUR/mėn.)    |          2.48  |          3     |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Namai plius Planas        | Dieninė energijos kaina (EUR/kWh) |          0.156 |          0.189 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Namai plius Planas        | Naktinė energijos kaina (EUR/kWh) |          0.102 |          0.124 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Išmanusis Planas          | Pastovioji dedamoji (EUR/mėn.)    |          4.96  |          6     |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Išmanusis Planas          | Dieninė energijos kaina (EUR/kWh) |          0.141 |          0.171 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Išmanusis Planas          | Naktinė energijos kaina (EUR/kWh) |          0.095 |          0.115 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Keturių laiko zonų Planas | Nakties energijos kaina (EUR/kWh) |          0.087 |          0.105 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Keturių laiko zonų Planas | Ryto energijos kaina (EUR/kWh)    |          0.098 |          0.118 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Keturių laiko zonų Planas | Dienos energijos kaina (EUR/kWh)  |          0.126 |          0.153 |
# +---------------------------+-----------------------------------+----------------+----------------+
# | Keturių laiko zonų Planas | Vakaro energijos kaina (EUR/kWh)  |          0.15  |          0.182 |
# +---------------------------+-----------------------------------+----------------+----------------+
# +----------------------------+----------------------------------------------------------------+----------------+----------------+
# | Tarifas                    | Dedamoji                                                       |   Kaina be PVM |   Kaina su PVM |
# +============================+================================================================+================+================+
# | Vienos laiko zonos tarifas | Vienos laiko zonos energijos dedamoji EUR/kWh                  |          0.106 |          0.128 |
# +----------------------------+----------------------------------------------------------------+----------------+----------------+
# | Dviejų laiko zonų tarifas  | Dieninė energijos dedamoji EUR/kWh                             |          0.121 |          0.146 |
# +----------------------------+----------------------------------------------------------------+----------------+----------------+
# | Dviejų laiko zonų tarifas  | Naktinė, Šeštadienio ir sekmadienio energijos dedamoji EUR/kWh |          0.083 |          0.1   |
# +----------------------------+----------------------------------------------------------------+----------------+----------------+

# %%
for i, el in enumerate(datos_tvarkymui):
    duomenu_sar.append([el, df_1, df_2])

# %%
print(duomenu_sar[15])
# Out:
# ['2022-12-31',                       Tarifas                           Dedamoji  \
# 0         Standartinis Planas     Pastovioji dedamoji (EUR/mėn.)
# 1         Standartinis Planas          Energijos kaina (EUR/kWh)
# 2                Namai Planas     Pastovioji dedamoji (EUR/mėn.)
# 3                Namai Planas          Energijos kaina (EUR/kWh)
# 4          Namai plius Planas     Pastovioji dedamoji (EUR/mėn.)
# 5          Namai plius Planas  Dieninė energijos kaina (EUR/kWh)
# 6          Namai plius Planas  Naktinė energijos kaina (EUR/kWh)
# 7            Išmanusis Planas     Pastovioji dedamoji (EUR/mėn.)
# 8            Išmanusis Planas  Dieninė energijos kaina (EUR/kWh)
# 9            Išmanusis Planas  Naktinė energijos kaina (EUR/kWh)
# 10  Keturių laiko zonų Planas  Nakties energijos kaina (EUR/kWh)
# 11  Keturių laiko zonų Planas     Ryto energijos kaina (EUR/kWh)
# 12  Keturių laiko zonų Planas   Dienos energijos kaina (EUR/kWh)
# 13  Keturių laiko zonų Planas   Vakaro energijos kaina (EUR/kWh)
#
#     Kaina be PVM  Kaina su PVM
# 0          2.480         3.000
# 1          0.138         0.167
# 2          4.960         6.000
# 3          0.125         0.151
# 4          2.480         3.000
# 5          0.156         0.189
# 6          0.102         0.124
# 7          4.960         6.000
# 8          0.141         0.171
# 9          0.095         0.115
# 10         0.087         0.105
# 11         0.098         0.118
# 12         0.126         0.153
# 13         0.150         0.182  ,                       Tarifas  \
# 0  Vienos laiko zonos tarifas
# 1   Dviejų laiko zonų tarifas
# 2   Dviejų laiko zonų tarifas
#
#                                             Dedamoji  Kaina be PVM  \
# 0      Vienos laiko zonos energijos dedamoji EUR/kWh         0.106
# 1                 Dieninė energijos dedamoji EUR/kWh         0.121
# 2  Naktinė, Šeštadienio ir sekmadienio energijos ...         0.083
#
#    Kaina su PVM
# 0         0.128
# 1         0.146
# 2         0.100  ]

# %%
import pickle
with open('Data_scrap.pkl', 'wb') as file:
    pickle.dump(duomenu_sar, file)

# %% [markdown]
# Alternatyvus duomenų suvedimas rankiniu būdu (panaudojant funkciją iš aukščiau):

# %%
# pirma_lent = []
# antra_lent = []

# while True:
#     prideti_lentele(pirma_lent)
#     more = input("Ar norite pridėti kitą įrašą? (taip/ne): ").lower()
#     if more != 'taip':
#         break

# df_1 = pd.DataFrame(pirma_lent)
# df_2 = pd.DataFrame(antra_lent)
# print(tabulate(df_1, headers='keys', tablefmt='grid', showindex=False))
# print(tabulate(df_2, headers='keys', tablefmt='grid', showindex=False))
